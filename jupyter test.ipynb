# %%
age = int(input('enter age: '))

# %%
print('you are '+ str(age) +' year old')
#sd'vk'sfbvkg'sfbkg'skgb'sk
s;lvg;s.gvmj;.sdvgjm;swdmjgv/;swmlg
#s;bjs;jb;szjb;sjb
# Out:
#   Cell In[4], line 3
#     s;lvg;s.gvmj;.sdvgjm;swdmjgv/;swmlg
#                  ^
# SyntaxError: invalid syntax
